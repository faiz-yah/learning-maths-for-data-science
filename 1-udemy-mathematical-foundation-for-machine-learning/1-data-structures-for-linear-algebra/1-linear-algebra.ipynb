# %% [markdown]
# # Linear Algebra

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## Tensors

# %% [markdown]
# -

# %% [markdown]
# ![image.png](attachment:image.png)
